# %%
import pandas as pd

# %%
df = pd.read_csv("survey_results_public.csv", index_col='ResponseId')
schema_df = pd.read_csv('survey_results_schema.csv',index_col = 'qname')

# %%
pd.set_option('display.max_columns',85)
pd.set_option('display.max_rows',85)

# %%
df.head()
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# 3                                          Student, full-time
# 4                                          Employed full-time
# 5           Independent contractor, freelancer, or self-em...
#
#                                                       Country US_State  \
# ResponseId
# 1                                                    Slovakia      NaN
# ...

# %%
df[['Country','Employment']]
# Out:
#                                                       Country  \
# ResponseId
# 1                                                    Slovakia
# 2                                                 Netherlands
# 3                                          Russian Federation
# 4                                                     Austria
# 5           United Kingdom of Great Britain and Northern I...
# ...                                                       ...
# 83435                                United States of America
# 83436                                                   Benin
# 83437                                United States of America
# 83438                                                  Canada
# 83439                                                  Brazil
#
#                                                    Employment
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# ...

# %%
type(df[['Country','Employment']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.loc[25:32, 'Country':'YearsCode']
# Out:
#                                                       Country US_State  \
# ResponseId
# 25                                                    Germany      NaN
# 26                                                    Germany      NaN
# 27                                                Switzerland      NaN
# 28          United Kingdom of Great Britain and Northern I...      NaN
# 29          United Kingdom of Great Britain and Northern I...      NaN
# 30                                         Russian Federation      NaN
# 31                                                     Malawi      NaN
# 32                                                     Israel      NaN
#
#            UK_Country                                            EdLevel  \
# ResponseId
# 25                NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 26                NaN         Other doctoral degree (Ph.D., Ed.D., etc.)
# 27                NaN    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...

# %%
df.set_index('ResponseId')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1204/146859209.py in <module>
# ----> 1 df.set_index('ResponseId')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5449
#    5450         if missing:
# -> 5451             raise KeyError(f"None of {missing} are in the columns")
#    5452
#    5453         if inplace:
#
# KeyError: "None of ['ResponseId'] are in the columns"

# %%
df.loc[1]
# Out:
# MainBranch                                         I am a developer by profession
# Employment                      Independent contractor, freelancer, or self-em...
# Country                                                                  Slovakia
# US_State                                                                      NaN
# UK_Country                                                                    NaN
# EdLevel                         Secondary school (e.g. American high school, G...
# Age1stCode                                                          18 - 24 years
# LearnCode                       Coding Bootcamp;Other online resources (ex: vi...
# YearsCode                                                                     NaN
# YearsCodePro                                                                  NaN
# DevType                                                         Developer, mobile
# ...

# %%
schema_df
# Out:
#                        qid                                           question  \
# qname
# S0                   QID16  <div><span style="font-size:19px;"><strong>Hel...
# MetaInfo             QID12                                  Browser Meta Info
# S1                    QID1  <span style="font-size:22px; font-family: aria...
# MainBranch            QID2  Which of the following options best describes ...
# Employment           QID24  Which of the following best describes your cur...
# Country               QID6  Where do you live? <span style="font-weight: b...
# US_State              QID7  <p>In which state or territory of the USA do y...
# UK_Country            QID9  In which part of the United Kingdom do you liv...
# S2                  QID190  <span style="font-size:22px; font-family: aria...
# EdLevel              QID25  Which of the following best describes the high...
# Age1stCode          QID149  At what age did you write your first line of c...
# ...

# %%
schema_df.index_sort()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1204/298865789.py in <module>
# ----> 1 schema_df.index_sort()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'index_sort'

# %%
filt_country = (df['Country'] == 'Netherlands')

# %%
df[filt_country]
# Out:
#                                                    MainBranch  \
# ResponseId
# 2                      I am a student who is learning to code
# 71          I am not primarily a developer, but I write co...
# 83                     I am a student who is learning to code
# 92          I am not primarily a developer, but I write co...
# 114                            I am a developer by profession
# ...                                                       ...
# 83040                          I am a developer by profession
# 83080                          I am a developer by profession
# 83106                          I am a developer by profession
# 83267                          I am a developer by profession
# 83410                          I am a developer by profession
#
#                     Employment      Country US_State UK_Country  \
# ResponseId
# 2           Student, full-time  Netherlands      NaN        NaN
# 71          Employed full-time  Netherlands      NaN        NaN
# ...

# %%
#same result as above
#can also select required column in this method
df.loc[filt_country]
#example
df.loc[filt_country,'YearsCode']
## NOTE ##
# '~' is used as NOT.#
# example #
# df.loc[~filt_country,'YearsCode'] #
# Out:
# ResponseId
# 2         7
# 71       10
# 83        5
# 92       20
# 127       4
#          ..
# 82825     8
# 83040    22
# 83080     8
# 83106    11
# 83267    26
# Name: YearsCode, Length: 1043, dtype: object

# %%
#AND OR METHOD TO FILTER
filt_country = (df['Country'] == 'Netherlands') & (df['Age1stCode'] == '11 - 17 years')
df[filt_country]
# Out:
#                                                    MainBranch  \
# ResponseId
# 2                      I am a student who is learning to code
# 71          I am not primarily a developer, but I write co...
# 83                     I am a student who is learning to code
# 92          I am not primarily a developer, but I write co...
# 127         I am not primarily a developer, but I write co...
# ...                                                       ...
# 82825                          I am a developer by profession
# 83040                          I am a developer by profession
# 83080                          I am a developer by profession
# 83106                          I am a developer by profession
# 83267                          I am a developer by profession
#
#                     Employment      Country US_State UK_Country  \
# ResponseId
# 2           Student, full-time  Netherlands      NaN        NaN
# 71          Employed full-time  Netherlands      NaN        NaN
# ...

# %%
df[filt_country]
# Out:
#                                                    MainBranch  \
# ResponseId
# 2                      I am a student who is learning to code
# 71          I am not primarily a developer, but I write co...
# 83                     I am a student who is learning to code
# 92          I am not primarily a developer, but I write co...
# 127         I am not primarily a developer, but I write co...
# ...                                                       ...
# 82825                          I am a developer by profession
# 83040                          I am a developer by profession
# 83080                          I am a developer by profession
# 83106                          I am a developer by profession
# 83267                          I am a developer by profession
#
#                     Employment      Country US_State UK_Country  \
# ResponseId
# 2           Student, full-time  Netherlands      NaN        NaN
# 71          Employed full-time  Netherlands      NaN        NaN
# ...

# %%
filt_country = (df['Country'] == 'Netherlands') | (df['Country'] == 'India')
filt_country
df[filt_country].head(4)
# Out:
#                                         MainBranch          Employment  \
# ResponseId
# 2           I am a student who is learning to code  Student, full-time
# 9                   I am a developer by profession  Employed part-time
# 23          I am a student who is learning to code  Student, full-time
# 40          I am a student who is learning to code  Student, part-time
#
#                 Country US_State UK_Country  \
# ResponseId
# 2           Netherlands      NaN        NaN
# 9                 India      NaN        NaN
# 23                India      NaN        NaN
# 40                India      NaN        NaN
#
#                                                       EdLevel     Age1stCode  \
# ResponseId
# 2                Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 9                Bachelor’s degree (B.A., B.S., B.Eng., etc.)  18 - 24 years
# 23          Some college/university study without earning ...   5 - 10 years
# ...

# %%
countries = ['United States', 'India', 'Canada']
filt = df['Country'].isin(countries)

# %%
df.loc[filt, 'Country']
# Out:
# Series([], Name: Country, dtype: object)

# %%
## To grab 'python' users alone ##
filt = df['LanguageHaveWorkedWith'].str.contains('Python', na=False)
df.loc[filt,'LanguageHaveWorkedWith']

## na=False because there are 'Nan' values entered which should be filled orelse we will get error ##
# Out:
# ResponseId
# 2                                        JavaScript;Python
# 3                                 Assembly;C;Python;R;Rust
# 5                           Bash/Shell;HTML/CSS;Python;SQL
# 6        C;C#;C++;HTML/CSS;Java;JavaScript;Node.js;Powe...
# 10                                              C++;Python
#                                ...
# 83430               HTML/CSS;PHP;PowerShell;Python;SQL;VBA
# 83431          APL;Clojure;LISP;Python;Ruby;SQL;TypeScript
# 83432    C#;Dart;HTML/CSS;Java;JavaScript;Kotlin;Node.j...
# 83437                                   Groovy;Java;Python
# 83438                 Bash/Shell;JavaScript;Node.js;Python
# Name: LanguageHaveWorkedWith, Length: 39792, dtype: object

# %%
## Modify data in DF ##

# %%
# change column name #
df.rename(columns={'EdLevel':'Edulevel'},inplace=True)
df
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 83435                          I am a developer by profession
# 83436                          I am a developer by profession
# 83437                          I am a developer by profession
# 83438                          I am a developer by profession
# 83439                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# ...

# %%
df.loc[2,['Country','US_State']] = ['USA','NYC']
df
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 83435                          I am a developer by profession
# 83436                          I am a developer by profession
# 83437                          I am a developer by profession
# 83438                          I am a developer by profession
# 83439                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# ...

# %%
# to change single value #
df.loc[2,'Country'] = 'Ntherlands'
df

# %%
##change on value##
filt = (df['US_State']=='NYC')
df.loc[filt,'Country']= 'USA'
df

# %%
## apply ##
df['Country'].apply(len)
# Out:
# ResponseId
# 1         8
# 2         3
# 3         5
# 4         7
# 5         5
#          ..
# 83435    24
# 83436     5
# 83437     5
# 83438     5
# 83439     6
# Name: Country, Length: 83439, dtype: int64

# %%
df.apply(pd.Series.min)
## can be used for numerical dataasets ##

# %%
df.applymap(str.lower)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1204/357608748.py in <module>
# ----> 1 df.applymap(str.lower)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in applymap(self, func, na_action, **kwargs)
#    8823             return lib.map_infer(x.astype(object)._values, func, ignore_na=ignore_na)
#    8824
# -> 8825         return self.apply(infer).__finalize__(self, "applymap")
#    8826
#    8827     # ----------------------------------------------------------------------
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8738             kwargs=kwargs,
#    8739         )
# -> 8740         return op.apply()
#    8741
#    8742     def applymap(
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
# ...

# %%
## replace ##
df['Country'].replace({"Russian Federation": "Soviet"},inplace=True)
df

# %%
## add new column ##
df['Address'] = df['US_State'] + ' ' + ['Country']

# %%
## to remove ##
df.drop(columns=['Country','US_State'])

# %%
## sort ##

# %%
df.sort_values(by=['Country'],inplace=True)

# %%
df['Country'].head(5)
# Out:
# ResponseId
# 39472    Afghanistan
# 62691    Afghanistan
# 62971    Afghanistan
# 62787    Afghanistan
# 26035    Afghanistan
# Name: Country, dtype: object

# %%
df.sort_values(by=['Country','CompTotal'],ascending = [True,False],inplace=True)

# %%
df[['Country','CompTotal']].head(5)
## pass through a list ##
# Out:
#                 Country  CompTotal
# ResponseId
# 65400       Afghanistan  4544242.0
# 22667       Afghanistan  1000000.0
# 31087       Afghanistan   154100.0
# 44641       Afghanistan    97333.0
# 11378       Afghanistan    63000.0

# %%
df['CompTotal'].nlargest(10)
# Out:
# ResponseId
# 6379     1.000000e+74
# 18920    8.000000e+52
# 62418    7.000000e+39
# 104      1.000000e+29
# 23553    1.000000e+25
# 45851    6.675636e+15
# 69036    4.162026e+15
# 39572    5.474577e+10
# 82157    3.500000e+10
# 37019    1.000000e+10
# Name: CompTotal, dtype: float64

# %%
df.nlargest(10,'CompTotal')
# Out:
#                                                    MainBranch  \
# ResponseId
# 6379                           I am a developer by profession
# 18920                          I am a developer by profession
# 62418                          I am a developer by profession
# 104                            I am a developer by profession
# 23553       I am not primarily a developer, but I write co...
# 45851                          I am a developer by profession
# 69036                          I am a developer by profession
# 39572                          I am a developer by profession
# 82157                          I am a developer by profession
# 37019                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 6379                                       Employed full-time
# 18920                                      Employed full-time
# 62418                                                 Retired
# ...

# %%
df['CompTotal'].head(10)
# Out:
# ResponseId
# 65400    4544242.0
# 22667    1000000.0
# 27199     480000.0
# 31087     154100.0
# 44641      97333.0
# 11378      63000.0
# 17487      35000.0
# 51429      30000.0
# 17121      20000.0
# 14883       6500.0
# Name: CompTotal, dtype: float64

# %%
## grouping/aggregation ##
df['CompTotal'].median()
# Out:
# 67000.0

# %%
df.median()
# Out:
# C:\Users\ADMIN1\AppData\Local\Temp/ipykernel_3756/530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# CompTotal              67000.0
# ConvertedCompYearly    56211.0
# dtype: float64

# %%
df.describe()
# Out:
#           CompTotal  ConvertedCompYearly
# count  4.718300e+04         4.684400e+04
# mean   2.119407e+69         1.184262e+05
# std    4.603702e+71         5.272944e+05
# min    0.000000e+00         1.000000e+00
# 25%    1.600000e+04         2.702500e+04
# 50%    6.700000e+04         5.621100e+04
# 75%    1.400000e+05         1.000000e+05
# max    1.000000e+74         4.524131e+07

# %%
df['SOAccount'].value_counts()
# Out:
# Yes                        67813
# No                         10510
# Not sure/can't remember     4202
# Name: SOAccount, dtype: int64

# %%
df['Currency']
# Out:
# ResponseId
# 65400    ANG Netherlands Antillean guilder
# 22667                  AFN\tAfghan afghani
# 27199                    JPY\tJapanese yen
# 31087                  AFN\tAfghan afghani
# 44641                  AFN\tAfghan afghani
#                        ...
# 56303                                  NaN
# 13195            USD\tUnited States dollar
# 80997                                  NaN
# 73742                                  NaN
# 38429            USD\tUnited States dollar
# Name: Currency, Length: 83439, dtype: object

# %%
df['Currency'].value_counts()
# Out:
# USD\tUnited States dollar      14363
# EUR European Euro              13932
# INR\tIndian rupee               6427
# GBP\tPound sterling             3547
# CAD\tCanadian dollar            2108
#                                ...
# SRD\tSurinamese dollar             1
# VUV\tVanuatu vatu                  1
# CDF\tCongolese franc               1
# PGK\tPapua New Guinean kina        1
# SHP\tSaint Helena pound            1
# Name: Currency, Length: 146, dtype: int64

# %%
## in percentage ##
df['Currency'].value_counts(normalize=True)
# Out:
# USD\tUnited States dollar      0.235151
# EUR European Euro              0.228094
# INR\tIndian rupee              0.105223
# GBP\tPound sterling            0.058071
# CAD\tCanadian dollar           0.034512
#                                  ...
# SRD\tSurinamese dollar         0.000016
# VUV\tVanuatu vatu              0.000016
# CDF\tCongolese franc           0.000016
# PGK\tPapua New Guinean kina    0.000016
# SHP\tSaint Helena pound        0.000016
# Name: Currency, Length: 146, dtype: float64

# %%
## Grouping ##

# %%
df["Country"].value_counts()
# Out:
# United States of America                                15288
# India                                                   10511
# Germany                                                  5625
# United Kingdom of Great Britain and Northern Ireland     4475
# Canada                                                   3012
#                                                         ...
# Liechtenstein                                               1
# Papua New Guinea                                            1
# Dominica                                                    1
# Saint Kitts and Nevis                                       1
# Saint Vincent and the Grenadines                            1
# Name: Country, Length: 181, dtype: int64

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group('India')
# Out:
#                                         MainBranch  \
# ResponseId
# 18920               I am a developer by profession
# 80178               I am a developer by profession
# 47844               I am a developer by profession
# 70275               I am a developer by profession
# 28792               I am a developer by profession
# ...                                            ...
# 644         I am a student who is learning to code
# 659                 I am a developer by profession
# 2062        I am a student who is learning to code
# 17630       I am a student who is learning to code
# 634         I am a student who is learning to code
#
#                                         Employment Country US_State  \
# ResponseId
# 18920                           Employed full-time   India      NaN
# 80178                           Employed full-time   India      NaN
# 47844                           Employed full-time   India      NaN
# ...

# %%
## filter method ##
filt = df['Country'] == "India"
df.loc[filt]
# Out:
#                                         MainBranch  \
# ResponseId
# 18920               I am a developer by profession
# 80178               I am a developer by profession
# 47844               I am a developer by profession
# 70275               I am a developer by profession
# 28792               I am a developer by profession
# ...                                            ...
# 644         I am a student who is learning to code
# 659                 I am a developer by profession
# 2062        I am a student who is learning to code
# 17630       I am a student who is learning to code
# 634         I am a student who is learning to code
#
#                                         Employment Country US_State  \
# ResponseId
# 18920                           Employed full-time   India      NaN
# 80178                           Employed full-time   India      NaN
# 47844                           Employed full-time   India      NaN
# ...

# %%
## filter method ##
filt = df['Country'] == "India"
df.loc[filt]['DatabaseWantToWorkWith'].value_counts()
# Out:
# MongoDB                                                                372
# MySQL                                                                  341
# MongoDB;MySQL                                                          237
# Firebase                                                               204
# PostgreSQL                                                             176
#                                                                       ...
# Elasticsearch;Oracle;Redis                                               1
# Cassandra;Elasticsearch;MySQL;SQLite                                     1
# DynamoDB;Firebase;MongoDB;Oracle;SQLite                                  1
# DynamoDB;Firebase;Microsoft SQL Server;PostgreSQL;SQLite                 1
# DynamoDB;Elasticsearch;Microsoft SQL Server;PostgreSQL;Redis;SQLite      1
# Name: DatabaseWantToWorkWith, Length: 1489, dtype: int64

# %%
country_grp['DatabaseWantToWorkWith'].value_counts()
# Out:
# Country      DatabaseWantToWorkWith
# Afghanistan  MongoDB;MySQL              4
#              MySQL                      3
#              MySQL;Oracle               2
#              Oracle;PostgreSQL          2
#              Cassandra                  1
#                                        ..
# Zimbabwe     MySQL;PostgreSQL           1
#              MySQL;PostgreSQL;Redis     1
#              MySQL;PostgreSQL;SQLite    1
#              MySQL;SQLite               1
#              PostgreSQL;SQLite          1
# Name: DatabaseWantToWorkWith, Length: 18475, dtype: int64

# %%
country_grp['DatabaseWantToWorkWith'].value_counts().loc['India']
# Out:
# DatabaseWantToWorkWith
# MongoDB                          372
# MySQL                            341
# MongoDB;MySQL                    237
# Firebase                         204
# PostgreSQL                       176
#                                 ...
# MySQL;Oracle;PostgreSQL;Redis      1
# Oracle;PostgreSQL;Redis            1
# Oracle;PostgreSQL;SQLite           1
# Oracle;Redis                       1
# Oracle;Redis;SQLite                1
# Name: DatabaseWantToWorkWith, Length: 1489, dtype: int64

# %%
country_grp['CompTotal'].median().loc["India"]
# Out:
# 622000.0

# %%
## aggregate ##
country_grp['CompTotal'].agg(['median','mean']).loc["India"]
# Out:
# median    6.220000e+05
# mean      2.052335e+49
# Name: India, dtype: float64

# %%
## python users ##
filt = df['Country'] == "India"
df.loc[filt]['LanguageHaveWorkedWith'].str.contains('Python')
# Out:
# ResponseId
# 18920    False
# 80178    False
# 47844     True
# 70275     True
# 28792     True
#          ...
# 644       True
# 659      False
# 2062     False
# 17630    False
# 634        NaN
# Name: LanguageHaveWorkedWith, Length: 10511, dtype: object

# %%
filt = df['Country'] == "India"
df.loc[filt]['LanguageHaveWorkedWith'].str.contains('Python').sum()
# Out:
# 5233

# %%
country_grp['LanguageHaveWorkedWith'].str.contains('Python').sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3756/3764435434.py in <module>
# ----> 1 country_grp['LanguageHaveWorkedWith'].str.contains('Python').sum()
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     909             return self[attr]
#     910
# --> 911         raise AttributeError(
#     912             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     913         )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'str'

# %%
## cannot access str in 'SeriesGroupBy' object, so use below method ##
# use 'apply' method #
## 'apply' function which u want to run in each series in the group ##

pyt = country_grp['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('Python').sum())

# %%
country_respondents = df['Country'].value_counts()
country_respondents
# Out:
# United States of America                                15288
# India                                                   10511
# Germany                                                  5625
# United Kingdom of Great Britain and Northern Ireland     4475
# Canada                                                   3012
#                                                         ...
# Liechtenstein                                               1
# Papua New Guinea                                            1
# Dominica                                                    1
# Saint Kitts and Nevis                                       1
# Saint Vincent and the Grenadines                            1
# Name: Country, Length: 181, dtype: int64

# %%
# percent #
# we can combine series using concat fn #
# create a new df #
python_df = pd.concat([country_respondents,pyt],axis='columns')
python_df
# Out:
#                                                     Country  \
# United States of America                              15288
# India                                                 10511
# Germany                                                5625
# United Kingdom of Great Britain and Northern Ir...     4475
# Canada                                                 3012
# ...                                                     ...
# Liechtenstein                                             1
# Papua New Guinea                                          1
# Dominica                                                  1
# Saint Kitts and Nevis                                     1
# Saint Vincent and the Grenadines                          1
#
#                                                     LanguageHaveWorkedWith
# United States of America                                              7975
# India                                                                 5233
# ...

# %%
python_df.rename(columns={'Country':'Numrespondents', 'LanguageHaveWorkedWith':'NumKnowsPyhton'}, inplace=True)
python_df
# Out:
#                                                     Numrespondents  \
# United States of America                                     15288
# India                                                        10511
# Germany                                                       5625
# United Kingdom of Great Britain and Northern Ir...            4475
# Canada                                                        3012
# ...                                                            ...
# Liechtenstein                                                    1
# Papua New Guinea                                                 1
# Dominica                                                         1
# Saint Kitts and Nevis                                            1
# Saint Vincent and the Grenadines                                 1
#
#                                                     NumKnowsPyhton
# United States of America                                      7975
# ...

# %%
python_df['Percent'] = (python_df['NumKnowsPyhton']/python_df['Numrespondents']) * 100

# %%
python_df
# Out:
#                                                     Numrespondents  \
# United States of America                                     15288
# India                                                        10511
# Germany                                                       5625
# United Kingdom of Great Britain and Northern Ir...            4475
# Canada                                                        3012
# ...                                                            ...
# Liechtenstein                                                    1
# Papua New Guinea                                                 1
# Dominica                                                         1
# Saint Kitts and Nevis                                            1
# Saint Vincent and the Grenadines                                 1
#
#                                                     NumKnowsPyhton     Percent
# United States of America                                      7975   52.165097
# ...

# %%
python_df.sort_values(by='Percent', ascending = False, inplace=True)
python_df.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1204/1031835148.py in <module>
# ----> 1 python_df.sort_values(by='Percent', ascending = False, inplace=True)
#       2 python_df.head(5)
#       3
#
# NameError: name 'python_df' is not defined

# %%
python_df.loc['Japan']
# Out:
# Numrespondents    429.000000
# NumKnowsPyhton    209.000000
# Percent            48.717949
# Name: Japan, dtype: float64

# %%
## casting ##

# %%
df['YearsCode'].head(10)
# Out:
# ResponseId
# 65400     7
# 22667     5
# 27199     3
# 31087    16
# 44641     7
# 11378     8
# 17487     7
# 51429     7
# 17121     3
# 14883     8
# Name: YearsCode, dtype: object

# %%
df['YearsCode'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3756/2991359917.py in <module>
# ----> 1 df['YearsCode'].mean()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10749         )
#   10750         def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 10751             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10752
#   10753         setattr(cls, "mean", mean)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10367
#   10368     def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 10369         return self._stat_function(
#   10370             "mean", nanops.nanmean, axis, skipna, level, numeric_only, **kwargs
# ...

# %%
df['YearsCode'] = df['YearsCode'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3756/1298014615.py in <module>
# ----> 1 df['YearsCode'] = df['YearsCode'].astype(float)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# ...

# %%
df['YearsCode'].unique()
# Out:
# array(['7', '5', '3', '16', '8', 'Less than 1 year', nan, '6', '2', '20',
#        '4', 'More than 50 years', '1', '10', '9', '11', '32', '23', '12',
#        '13', '25', '30', '15', '18', '14', '46', '19', '17', '36', '37',
#        '35', '26', '40', '28', '38', '31', '33', '24', '22', '34', '41',
#        '27', '21', '29', '45', '42', '48', '50', '39', '43', '47', '49',
#        '44'], dtype=object)

# %%
df['YearsCode'].replace('Less than 1 year',0,inplace= True)

# %%
df['YearsCode'].replace('More than 50 years',51,inplace= True)

# %%
df['YearsCode'].unique()
# Out:
# array(['7', '5', '3', '16', '8', 0, nan, '6', '2', '20', '4', 51, '1',
#        '10', '9', '11', '32', '23', '12', '13', '25', '30', '15', '18',
#        '14', '46', '19', '17', '36', '37', '35', '26', '40', '28', '38',
#        '31', '33', '24', '22', '34', '41', '27', '21', '29', '45', '42',
#        '48', '50', '39', '43', '47', '49', '44'], dtype=object)

# %%
df['YearsCode'] = df['YearsCode'].astype(float)

# %%
df['YearsCode'].mean()
# Out:
# 12.338200169032717
